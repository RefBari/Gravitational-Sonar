# %% [markdown]
# # Gravitational Sonar v16 — JAX accelerated
#
# Physics preserved from `Sonar_v16_GoldenRun16a`: same metric ansatz,
# Hamiltonian, dissipation, RK4 rule, numerical-kludge waveform, Ricci
# tensor, boundary condition, loss weights, initial conditions, and
# Adam → BFGS/SSBroyden2 schedule.
#
# Backend-only changes:
#
# - one compiled loss/gradient with `jax.jit`
# - RK4 time evolution with `jax.lax.scan`
# - Ricci, boundary, observer, and diagnostic grids with `jax.vmap`
# - quadrupole and polarization loops replaced by equivalent `einsum`
# - network stored as a 69-scalar JAX pytree
#
# **Colab:** choose a GPU runtime before running. First call for each
# window/dtype compiles; time subsequent calls, not compilation.

# %% [markdown]
# ## Setup

# %%
# Colab already ships JAX. This only supplies the original custom BFGS patch.
# !wget -q -nc https://raw.githubusercontent.com/EliKiani/Optimizing_the_Optimizer_PINNs/main/_optimize.py
# !sed -i 's/^from \.\([a-zA-Z_]*\) import/from scipy.optimize.\1 import/' _optimize.py

# %%
import math
import os
import time
from pathlib import Path

import jax
jax.config.update("jax_enable_x64", True)  # needed by the original BFGS handoff
import jax.numpy as jnp
from jax import lax, random, tree_util
from jax.flatten_util import ravel_pytree
import matplotlib.pyplot as plt
import numpy as np
from scipy import optimize
from scipy.optimize import minimize

print("JAX:", jax.__version__)
print("Devices:", jax.devices())
if jax.default_backend() == "cpu":
    print("WARNING: CPU backend. In Colab select Runtime > Change runtime type > GPU.")

Array = jax.Array
# Out:
# JAX: 0.7.2
# Devices: [CudaDevice(id=0)]

# %% [markdown]
# ## Data and physical inputs

# %%
DATA_DIR = Path("/content")
FILE_TAG = "Kerr_rp10_ra14noise0.0_massRatio1000.0spin_0.9inclination_0.7853981633974483_time1260_observertheta_0.7853981633974483"

t_true, hp_np = np.loadtxt(DATA_DIR / f"waveform_real_{FILE_TAG}.txt", unpack=True)
_, hc_np = np.loadtxt(DATA_DIR / f"waveform_imag_{FILE_TAG}.txt", unpack=True)
soln_true = np.loadtxt(DATA_DIR / f"solution_{FILE_TAG}.txt", unpack=True)

rp_true = 10.0
ra_true = 14.0
a_true = 0.9
theta_min_true = math.pi / 4
theta_observed = jnp.asarray([math.pi / 4], dtype=jnp.float32)

# Exact original grid: 1,000 coordinate-time samples over [0, 1260].
t_full = jnp.linspace(0.0, 1260.0, 1000, dtype=jnp.float32)
hp_full = jnp.asarray(hp_np[: len(t_full)], dtype=jnp.float32)[None, :]
hc_full = jnp.asarray(hc_np[: len(t_full)], dtype=jnp.float32)[None, :]

dt_np = np.diff(np.asarray(t_full))
assert np.allclose(dt_np, dt_np[0], rtol=1e-3), "t must be uniform"
print("samples:", len(t_full), "observers:", len(theta_observed))
# Out:
# samples: 1000 observers: 1

# %% [markdown]
# ## 69-parameter metric network and unchanged ansatz

# %%
def init_network(key, dtype=jnp.float32):
    # Same Linear(2,8) -> SiLU -> Linear(8,5) architecture: 69 scalars.
    k1, k2, k3, k4 = random.split(key, 4)
    l1 = 1.0 / math.sqrt(2.0)
    l2 = 1.0 / math.sqrt(8.0)
    return {
        "w1": random.uniform(k1, (8, 2), dtype, -l1, l1),
        "b1": random.uniform(k2, (8,), dtype, -l1, l1),
        "w2": random.uniform(k3, (5, 8), dtype, -l2, l2),
        "b2": random.uniform(k4, (5,), dtype, -l2, l2),
    }


def network_apply(params, x):
    hidden = jax.nn.silu(params["w1"] @ x + params["b1"])
    return params["w2"] @ hidden + params["b2"]


def nn_input(r, theta):
    return jnp.stack((1.0 / r, jnp.cos(theta) ** 2))


def Kerr(x, a, M=1.0):
    r, theta = x[1], x[2]
    delta = r**2 - 2.0 * M * r + a**2
    sigma = r**2 + a**2 * jnp.cos(theta) ** 2
    A = (r**2 + a**2) ** 2 - delta * a**2 * jnp.sin(theta) ** 2
    g_tt = -(1.0 - 2.0 * M * r / sigma)
    g_rr = sigma / delta
    g_thth = sigma
    g_phph = A / sigma * jnp.sin(theta) ** 2
    g_tph = (-2.0 * M * r / sigma) * a * jnp.sin(theta) ** 2
    z = jnp.zeros_like(r)
    return jnp.stack((
        jnp.stack((g_tt, z, z, g_tph)),
        jnp.stack((z, g_rr, z, z)),
        jnp.stack((z, z, g_thth, z)),
        jnp.stack((g_tph, z, z, g_phph)),
    ))


def g_Kerr(r, theta, M=1.0, a=a_true):
    return Kerr(jnp.stack((jnp.zeros_like(r), r, theta, jnp.zeros_like(r))), a, M)


def NN_Ansatz(r, theta, fields):
    u = 1.0 / r
    g_tt = -1.0 + u * fields[0]
    g_rr = 1.0 / (1.0 + u * fields[1])
    g_thth = r**2 + fields[2]
    g_phph = jnp.sin(theta) ** 2 * (r**2 + fields[3])
    g_tph = u * jnp.sin(theta) ** 2 * fields[4]
    z = jnp.zeros_like(r)
    return jnp.stack((
        jnp.stack((g_tt, z, z, g_tph)),
        jnp.stack((z, g_rr, z, z)),
        jnp.stack((z, z, g_thth, z)),
        jnp.stack((g_tph, z, z, g_phph)),
    ))


def metric_from_network(params, r, theta):
    return NN_Ansatz(r, theta, network_apply(params, nn_input(r, theta)))


params = init_network(random.PRNGKey(0))
flat0, _ = ravel_pytree(params)
assert flat0.size == 69
print("parameters:", flat0.size, "test output:", network_apply(params, jnp.array([2.0, 1.57])))
# Out:
# parameters: 69 test output: [-0.61378847  0.65292454  0.55026903 -0.2847634  -0.58163525]

# %%
R_LO, R_HI = 6.2, 20.0
TH_LO, TH_HI = 0.1, math.pi/2 - 0.1

def logit(x):
    x = jnp.clip(x, 1e-6, 1 - 1e-6)
    return jnp.log(x) - jnp.log1p(-x)

def inv_softplus(x):
    return jnp.log(jnp.expm1(x))

def encode_ic(r, theta, pt, Lz):
    return jnp.asarray([
        logit((r - R_LO) / (R_HI - R_LO)),
        logit((theta - TH_LO) / (TH_HI - TH_LO)),
        inv_softplus(-pt),
        inv_softplus(Lz),
    ], dtype=jnp.float32)

def decode_ic(z):
    r = R_LO + (R_HI - R_LO) * jax.nn.sigmoid(z[0])
    theta = TH_LO + (TH_HI - TH_LO) * jax.nn.sigmoid(z[1])
    pt = -jax.nn.softplus(z[2])
    Lz = jax.nn.softplus(z[3])
    return jnp.asarray([0., r, theta, 0., pt, 0., 0., Lz])

params = {
    "metric": params,
    "ic": encode_ic(9.0, 0.90, -0.90, 2.30),
}

assert ravel_pytree(params)[0].size == 73

# %% [markdown]
# ## Initial conditions — unchanged Kerr map, evaluated once outside JIT

# %%
def solve_ELQ(r_p, r_a, theta_min, M=1.0, a=a_true, mu=1.0):
    delta_p = r_p**2 - 2.0 * M * r_p + a**2
    delta_a = r_a**2 - 2.0 * M * r_a + a**2

    def equations(v):
        E, Lz = v
        Qp = (((r_p**2 + a**2) * E - a * Lz) ** 2
              - delta_p * ((Lz - a * E) ** 2 + mu**2 * r_p**2)) / delta_p
        F0 = (((r_a**2 + a**2) * E - a * Lz) ** 2
              - delta_a * ((Lz - a * E) ** 2 + mu**2 * r_a**2 + Qp))
        F1 = Qp - math.cos(theta_min) ** 2 * (
            a**2 * (mu**2 - E**2) + Lz**2 / math.sin(theta_min) ** 2
        )
        return (F0, F1)

    E0 = math.sqrt(1.0 - 2.0 * M / (r_p + r_a))
    L0 = math.sqrt(M * (r_p + r_a) / 2.0)
    E, Lz = optimize.fsolve(equations, (E0, L0))
    Q = ((((r_p**2 + a**2) * E - a * Lz) ** 2
         - delta_p * ((Lz - a * E) ** 2 + mu**2 * r_p**2)) / delta_p)
    return E, Lz, Q


def make_u0(r_p, r_a, theta_min, M=1.0, a=a_true, mu=1.0):
    E, Lz, _ = solve_ELQ(r_p, r_a, theta_min, M, a, mu)
    return np.asarray([0.0, r_p, theta_min, 0.0, -E, 0.0, 0.0, Lz])


# solve_ELQ is not part of training AD: original ICs are fixed.
U0 = jnp.asarray(make_u0(rp_true, ra_true, theta_min_true), dtype=jnp.float64)
print("u0:", U0)
# Out:
# u0: [ 0.         10.          0.78539816  0.         -0.96048519  0.
#   0.          2.66185247]

# %% [markdown]
# ## Hamiltonian and RK4 — same equations, `lax.scan` time loop

# %%
I4 = jnp.eye(4)
Z4 = jnp.zeros((4, 4))
SYMPLECTIC = jnp.block([[Z4, I4], [-I4, Z4]])
DISSIPATION = -10e-4 * jnp.asarray([0, 0, 0, 0, 0, 0, 0, 1])


def hamiltonian_network(params, state):
    _, r, theta, _, p_t, p_r, p_theta, p_phi = state
    inv_g = jnp.linalg.inv(metric_from_network(params, r, theta))
    p = jnp.stack((p_t, p_r, p_theta, p_phi))
    return 0.5 * p @ inv_g @ p


def H_function(params, state):
    grad_H = jax.grad(hamiltonian_network, argnums=1)(params, state)
    du_dtau = SYMPLECTIC.astype(state.dtype) @ grad_H + DISSIPATION.astype(state.dtype)
    du = du_dtau / grad_H[4]
    return du.at[0].set(1.0)


def hamiltonian_kerr(state):
    inv_g = jnp.linalg.inv(Kerr(state[:4], a_true))
    return 0.5 * state[4:] @ inv_g @ state[4:]


def H_Kerr(state):
    grad_H = jax.grad(hamiltonian_kerr)(state)
    du_dtau = SYMPLECTIC.astype(state.dtype) @ grad_H + DISSIPATION.astype(state.dtype)
    du = du_dtau / grad_H[4]
    return du.at[0].set(1.0)


def rk4_step(rhs, time, state, step):
    k1 = rhs(time, state)
    k2 = rhs(time + step / 2.0, state + step * k1 / 2.0)
    k3 = rhs(time + step / 2.0, state + step * k2 / 2.0)
    k4 = rhs(time + step, state + step * k3)
    return state + step * (k1 + 2.0 * k2 + 2.0 * k3 + k4) / 6.0


def integrate(rhs, y0, t_array):
    step = t_array[1] - t_array[0]

    def scan_step(state, time):
        next_state = rk4_step(rhs, time, state, step)
        return next_state, next_state

    _, tail = lax.scan(scan_step, y0, t_array[:-1])
    return jnp.concatenate((y0[None, :], tail), axis=0)


def integrate_network(params, y0, t_array):
    return integrate(lambda time, state: H_function(params, state), y0, t_array)


def integrate_kerr(y0, t_array):
    return integrate(lambda time, state: H_Kerr(state), y0, t_array)

# %% [markdown]
# ## Numerical-kludge waveform — identical algebra, vectorized

# %%
def d2_dt2(v, dt):
    first = 2.0 * v[..., 0] - 5.0 * v[..., 1] + 4.0 * v[..., 2] - v[..., 3]
    middle = v[..., :-2] - 2.0 * v[..., 1:-1] + v[..., 2:]
    last = 2.0 * v[..., -1] - 5.0 * v[..., -2] + 4.0 * v[..., -3] - v[..., -4]
    return jnp.concatenate((first[..., None], middle, last[..., None]), axis=-1) / dt**2


def Soln2Orbit(soln, a):
    r, theta, phi = soln[:, 1], soln[:, 2], soln[:, 3]
    return jnp.stack((
        r * jnp.sin(theta) * jnp.cos(phi),
        r * jnp.sin(theta) * jnp.sin(phi),
        r * jnp.cos(theta),
    ))


def Q_ij(orbit, mu=1.0):
    outer = jnp.einsum("in,jn->ijn", orbit, orbit)
    r2 = jnp.sum(orbit**2, axis=0)
    return mu * (outer - jnp.eye(3, dtype=orbit.dtype)[:, :, None] * r2[None, None, :] / 3.0)


def Observer_Basis(theta_obs, phi_obs):
    n = jnp.stack((jnp.sin(theta_obs) * jnp.cos(phi_obs),
                   jnp.sin(theta_obs) * jnp.sin(phi_obs),
                   jnp.cos(theta_obs)))
    p = jnp.stack((jnp.cos(theta_obs) * jnp.cos(phi_obs),
                   jnp.cos(theta_obs) * jnp.sin(phi_obs),
                  -jnp.sin(theta_obs)))
    q = jnp.stack((-jnp.sin(phi_obs), jnp.cos(phi_obs), jnp.zeros_like(phi_obs)))
    return n, p, q


def project_waveform(Qdd, theta_obs=0.0, phi_obs=0.0, D=1.0):
    _, p, q = Observer_Basis(theta_obs, phi_obs)
    e_plus = jnp.einsum("i,j->ij", p, p) - jnp.einsum("i,j->ij", q, q)
    e_cross = jnp.einsum("i,j->ij", p, q) + jnp.einsum("i,j->ij", q, p)
    return (jnp.einsum("ij,ijn->n", e_plus, Qdd) / D,
            jnp.einsum("ij,ijn->n", e_cross, Qdd) / D)


def create_gravityWave(t_array, soln, a, mu=1.0, theta_obs=0.0, phi_obs=0.0, D=1.0):
    orbit = Soln2Orbit(soln, a)
    Qdd = d2_dt2(Q_ij(orbit, mu), t_array[1] - t_array[0])
    return project_waveform(Qdd, theta_obs, phi_obs, D)

# %% [markdown]
# ## Curvature and boundary terms — full-grid `vmap`

# %%
def christ_awful(metric, x):
    partial_g = jax.jacfwd(metric)(x)
    ginv = jnp.linalg.inv(metric(x))
    term1 = jnp.einsum("ms,sab->mab", ginv, partial_g)
    term2 = jnp.einsum("ms,sba->mab", ginv, partial_g)
    term3 = jnp.einsum("ms,abs->mab", ginv, partial_g)
    return 0.5 * (term1 + term2 - term3)


def Riemann(metric, x):
    dGamma = jax.jacfwd(lambda y: christ_awful(metric, y))(x)
    Gamma = christ_awful(metric, x)  # one evaluation; original recomputed it four times
    term1 = jnp.einsum("abvu->abuv", dGamma)
    term2 = jnp.einsum("abuv->abuv", dGamma)
    term3 = jnp.einsum("aup,pbv->abuv", Gamma, Gamma)
    term4 = jnp.einsum("avp,pbu->abuv", Gamma, Gamma)
    return term1 - term2 + term3 - term4


def Ricci(metric, x):
    return jnp.einsum("abav->bv", Riemann(metric, x))


R_INNER = jnp.logspace(math.log10(2.0), math.log10(20.0), 20)
R_OUTER = jnp.asarray([30.0, 50.0, 100.0, 200.0])
THETA_RICCI = jnp.linspace(math.pi / 20.0, math.pi / 2.0, 4)
RR, TT = jnp.meshgrid(jnp.concatenate((R_INNER, R_OUTER)), THETA_RICCI, indexing="ij")
RICCI_POINTS = jnp.stack((jnp.zeros(RR.size), RR.ravel(), TT.ravel(), jnp.zeros(RR.size)), axis=1)
BC_R = jnp.linspace(1.0, 2.01, 80)
BC_THETA = jnp.linspace(0.0, math.pi / 2.0, 4)


def ricci_loss(params):
    metric = lambda x: metric_from_network(params, x[1], x[2])
    points = RICCI_POINTS.astype(params["w1"].dtype)
    values = jax.vmap(lambda x: Ricci(metric, x))(points)
    return jnp.mean(jnp.sum(values**2, axis=(1, 2)))


def boundaryConditionLoss(params):
    dtype = params["w1"].dtype
    r_vals = BC_R.astype(dtype)
    theta_vals = BC_THETA.astype(dtype)
    tau = jnp.asarray(1e-4, dtype=dtype)

    def one_theta(theta):
        points = jnp.stack((jnp.zeros_like(r_vals), r_vals,
                            jnp.full_like(r_vals, theta), jnp.zeros_like(r_vals)), axis=1)
        residuals = jax.vmap(
            lambda x: 1.0 / metric_from_network(params, x[1], x[2])[1, 1]
        )(points)
        weights = jax.nn.softmax(-(residuals**2) / tau)
        root = jnp.sum(weights * r_vals)
        root_residual = 1.0 / metric_from_network(params, root, theta)[1, 1]
        sign_penalty = jax.nn.relu(residuals[0] * residuals[-1])
        return root, root_residual**2, sign_penalty

    roots, root_residuals, sign_penalties = jax.vmap(one_theta)(theta_vals)
    # torch.var default used correction=1; preserve that convention.
    location_consistency = jnp.var(roots, ddof=1)
    total = location_consistency + jnp.mean(root_residuals) + jnp.mean(sign_penalties)
    return total, roots

# %% [markdown]
# ## Loss — one compiled value/gradient

# %%
def mass_shell_loss(metric_params, u0):
    g = metric_from_network(metric_params, u0[1], u0[2])
    p = u0[4:]
    return (p @ jnp.linalg.inv(g) @ p + 1.0)**2


def hann_periodic(N, dtype):
    n = jnp.arange(N, dtype=dtype)
    return 0.5 * (1.0 - jnp.cos(2.0 * jnp.pi * n / N))


def SpectralLoss(h_true, h_pred):
    window = hann_periodic(h_true.shape[0], h_true.real.dtype)
    true_mag = jnp.abs(jnp.fft.fft(window * h_true))
    pred_mag = jnp.abs(jnp.fft.fft(window * h_pred))
    eps = 1e-4 * jnp.mean(true_mag**2)
    return jnp.mean((true_mag - pred_mag) ** 2 / (true_mag**2 + eps))

def waveform_loss(metric_params, u0, t_array, hp_true, hc_true, eps=1e-12):
    trajectory = integrate_network(metric_params, u0, t_array)
    observers = theta_observed.astype(metric_params["w1"].dtype)

    hp_pred, hc_pred = jax.vmap(
        lambda theta: create_gravityWave(
            t_array, trajectory, a_true, theta_obs=theta
        )
    )(observers)

    squared_error = jnp.mean(
        (hp_pred - hp_true)**2 + (hc_pred - hc_true)**2,
        axis=1,
    )
    truth_power = lax.stop_gradient(
        jnp.mean(hp_true**2 + hc_true**2, axis=1)
    )

    return (
        jnp.mean(squared_error / (truth_power + eps)),
        hp_pred,
        hc_pred,
    )


LOSS_WEIGHTS = jnp.asarray([1.0, 0.5, 0.1, 0.1])
P_MASS_SHELL = 10.0


def loss(joint, t_array, hp_true, hc_true, weights):
    metric_params = joint["metric"]
    u0 = decode_ic(joint["ic"])

    waveformLoss, hp_pred, hc_pred = waveform_loss(
        metric_params, u0, t_array, hp_true, hc_true
    )
    ricciLoss = ricci_loss(metric_params)
    boundaryLoss, roots = boundaryConditionLoss(metric_params)
    frequencyLoss = SpectralLoss(
        hp_true[0] + 1j * hc_true[0],
        hp_pred[0] + 1j * hc_pred[0],
    )
    shellLoss = mass_shell_loss(metric_params, u0)

    components = jnp.stack((
        waveformLoss,
        ricciLoss,
        frequencyLoss,
        boundaryLoss,
    ))

    total = (
        jnp.dot(weights.astype(components.dtype), components)
        + P_MASS_SHELL * shellLoss
    )

    return total, (components, roots, shellLoss, u0)


loss_value_and_grad = jax.jit(
    jax.value_and_grad(loss, argnums=0, has_aux=True)
)
loss_only = jax.jit(loss)

# %% [markdown]
# ## Physics gates

# %%
@jax.jit
def exact_kerr_gate(t_array):
    trajectory = integrate_kerr(U0.astype(t_array.dtype), t_array)
    return trajectory, create_gravityWave(
        t_array, trajectory, a_true, theta_obs=theta_observed[0].astype(t_array.dtype)
    )


trajectory_gate, (hp_gate, hc_gate) = exact_kerr_gate(t_full)
relative_L2 = 100.0 * jnp.linalg.norm((hp_gate + 1j * hc_gate) - (hp_full[0] + 1j * hc_full[0])) / (
    jnp.linalg.norm(hp_full[0] + 1j * hc_full[0]) + 1e-12
)
print("Exact-Kerr waveform L2 error (%):", float(relative_L2))

x_gate = jnp.asarray([0.0, 10.0, math.pi / 2.0, 0.0], dtype=jnp.float64)
print("Kerr Ricci gate:\n", Ricci(lambda x: Kerr(x, a_true), x_gate))
assert np.isfinite(np.asarray(relative_L2))
# Out:
# Exact-Kerr waveform L2 error (%): 0.3517760932445526
# Kerr Ricci gate:
#  [[ 2.16840434e-19  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  6.93889390e-18 -1.03518735e-33  0.00000000e+00]
#  [ 0.00000000e+00 -3.55093333e-33  5.55111512e-17  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  9.43689571e-16]]

# %%
# Matched-forward control: train on waveform generated by this JAX forward model
hp_full = hp_gate[None, :]
hc_full = hc_gate[None, :]

print("MATCHED-FORWARD TARGET ENABLED")
# Out:
# MATCHED-FORWARD TARGET ENABLED

# %% [markdown]
# ## Checkpoints

# %%
try:
    from google.colab import drive
    drive.mount("/content/drive")
    SAVE_DIR = Path("/content/drive/MyDrive")
except ImportError:
    SAVE_DIR = Path(".")

RUN_ID = "joint_ic_metric_matched_forward_seed0_long"
RESUME = False

CHECKPOINT_PATH = SAVE_DIR / f"{RUN_ID}_live.npz"
FINAL_PATH = SAVE_DIR / f"{RUN_ID}_final.npz"

def save_checkpoint(path, params, stage_idx, epoch, n, histories):
    flat, _ = ravel_pytree(params)
    np.savez(
        path,
        flat_params=np.asarray(jax.device_get(flat)),
        stage_idx=stage_idx,
        epoch=epoch,
        n=n,
        **{name: np.asarray(values) for name, values in histories.items()},
    )


def load_checkpoint(path, template):
    if not Path(path).exists():
        return None
    data = np.load(path)
    _, unravel = ravel_pytree(template)
    loaded = unravel(jnp.asarray(data["flat_params"]))
    names = (
        "total", "waveform", "ricci",
        "frequency", "boundary", "mass_shell",
        "monitor_ic", "monitor_metric",
    )
    histories = {
        name: data[name].tolist() if name in data else []
        for name in names
    }
    return loaded, int(data["stage_idx"]), int(data["epoch"]), int(data["n"]), histories


def import_pytorch_checkpoint(path):
    '''Optional one-time import of the original .pt network weights.'''
    import torch
    payload = torch.load(path, map_location="cpu")
    state = payload.get("net_state", payload)
    return {
        "w1": jnp.asarray(state["fc1.weight"].detach().numpy()),
        "b1": jnp.asarray(state["fc1.bias"].detach().numpy()),
        "w2": jnp.asarray(state["fc2.weight"].detach().numpy()),
        "b2": jnp.asarray(state["fc2.bias"].detach().numpy()),
    }

# To continue from a trained PyTorch model, uncomment before training:
# params = import_pytorch_checkpoint("/content/drive/MyDrive/sonar_v16_final.pt")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Adam — same curriculum, JIT loss/gradient

# %%
def tree_zeros_like(tree):
    return tree_util.tree_map(jnp.zeros_like, tree)


def global_norm(tree):
    return jnp.sqrt(sum(jnp.vdot(x, x).real for x in tree_util.tree_leaves(tree)))


@jax.jit
def adam_update(params, grads, state, learning_rate):
    count, m, v = state
    count = count + 1
    grad_norm = global_norm(grads)
    scale = jnp.minimum(1.0, 1.0 / (grad_norm + 1e-12))
    grads = tree_util.tree_map(lambda g: g * scale, grads)
    m = tree_util.tree_map(lambda old, g: 0.9 * old + 0.1 * g, m, grads)
    v = tree_util.tree_map(lambda old, g: 0.999 * old + 0.001 * g * g, v, grads)
    mhat = tree_util.tree_map(lambda x: x / (1.0 - 0.9**count), m)
    vhat = tree_util.tree_map(lambda x: x / (1.0 - 0.999**count), v)
    params = tree_util.tree_map(
        lambda p, mm, vv: p - learning_rate * mm / (jnp.sqrt(vv) + 1e-8),
        params, mhat, vhat,
    )
    return params, (count, m, v), grad_norm


def metric_errors(params):
    metric_params = params["metric"]

    radii = jnp.asarray(
        [2, 3, 4, 5, 6, 12, 20],
        dtype=metric_params["w1"].dtype,
    )
    angles = jnp.asarray(
        [math.pi / 20, math.pi / 4, math.pi / 3, math.pi / 2],
        dtype=metric_params["w1"].dtype,
    )

    def errors_at_r(r):
        pred = jax.vmap(
            lambda th: metric_from_network(metric_params, r, th)
        )(angles)

        true = jax.vmap(
            lambda th: g_Kerr(r, th)
        )(angles)

        ij = jnp.asarray([
            [0, 0],
            [1, 1],
            [2, 2],
            [3, 3],
            [0, 3],
        ])

        return jax.vmap(
            lambda pair:
                100.0
                * jnp.linalg.norm(
                    pred[:, pair[0], pair[1]]
                    - true[:, pair[0], pair[1]]
                )
                / (
                    jnp.linalg.norm(
                        true[:, pair[0], pair[1]]
                    )
                    + 1e-12
                )
        )(ij)

    return jax.vmap(errors_at_r)(radii).T


metric_errors_jit = jax.jit(metric_errors)

histories = {name: [] for name in (
    "total", "waveform", "ricci",
    "frequency", "boundary", "mass_shell",
    "monitor_ic", "monitor_metric",
)}

def record_monitor(current_params):
    u = np.asarray(
        jax.device_get(decode_ic(current_params["ic"])),
        dtype=float,
    )

    # Mean error for each metric component over r >= 3.
    metric_error = np.asarray(
        jax.device_get(metric_errors_jit(current_params)),
        dtype=float,
    )[:, 1:].mean(axis=1)

    histories["monitor_ic"].append([
        u[1],       # r
        u[2],       # theta
        -u[4],      # E
        u[7],       # Lz
    ])
    histories["monitor_metric"].append(metric_error)

schedule = [(25, 45), (50, 40), (100, 35)]  # exact original warm-up
n = 0
start_stage_idx = 0
start_epoch = 0

if RESUME:
    restored = load_checkpoint(CHECKPOINT_PATH, params)
    if restored is not None:
        params, start_stage_idx, saved_epoch, n, histories = restored
        start_epoch = saved_epoch + 1
        print("resumed:", start_stage_idx, start_epoch, n)

if not histories["monitor_ic"]:
    record_monitor(params)

adam_state = (jnp.asarray(0), tree_zeros_like(params), tree_zeros_like(params))
start_time = time.time()
LOG_EVERY = 10  # logging only; physics/loss unchanged

for stage_idx, (window, epochs) in enumerate(schedule):
    if stage_idx < start_stage_idx:
        continue
    t_window = t_full[:window]
    hp_window = hp_full[:, :window]
    hc_window = hc_full[:, :window]
    epoch0 = start_epoch if stage_idx == start_stage_idx else 0
    learning_rate = jnp.asarray(1e-2, dtype=params["metric"]["w1"].dtype)
    print(f"\nAdam {stage_idx + 1}/{len(schedule)}: [0:{window}], {epochs} iterations")

    for epoch in range(epoch0, epochs):
        (value_aux, grads) = loss_value_and_grad(
            params, t_window, hp_window, hc_window, LOSS_WEIGHTS
        )
        total, (components, roots, shell, u0_fit) = value_aux
        params, adam_state, grad_norm = adam_update(params, grads, adam_state, learning_rate)
        total.block_until_ready()

        if (n + 1) % 10 == 0:
          print(
              f"r0={float(u0_fit[1]):.6f}  "
              f"theta0={float(u0_fit[2]):.6f}  "
              f"E0={float(-u0_fit[4]):.6f}  "
              f"Lz0={float(u0_fit[7]):.6f}  "
              f"shell={float(shell):.3e}"
          )

        values = np.asarray(jax.device_get(components))
        histories["total"].append(float(total))
        for name, value, weight in zip(
            ("waveform", "ricci", "frequency", "boundary"), values, np.asarray(LOSS_WEIGHTS)
        ):
            histories[name].append(float(weight * value))
        histories["mass_shell"].append(
            float(P_MASS_SHELL * shell)
        )
        n += 1
        if n == 1 or n % LOG_EVERY == 0:
            record_monitor(params)
            elapsed = time.time() - start_time
            print(f"iter={n:4d} time={elapsed:7.1f}s total={float(total):.3e} "
                  f"W={values[0]:.2e} R={values[1]:.2e} F={values[2]:.2e} "
                  f"BC={values[3]:.2e} r_H={float(jnp.mean(roots)):.4f} |g|={float(grad_norm):.2e}")
        if n % 10 == 0:
            save_checkpoint(CHECKPOINT_PATH, params, stage_idx, epoch, n, histories)

    save_checkpoint(CHECKPOINT_PATH, params, stage_idx, epochs - 1, n, histories)

print("Adam complete:", n, "iterations")
# Out:
# Adam 1/3: [0:25], 45 iterations
# iter=   1 time=   24.3s total=3.949e+00 W=2.49e+00 R=2.18e-02 F=4.63e-01 BC=2.98e+00 r_H=2.0100 |g|=1.68e+01
# r0=9.204384  theta0=0.929401  E0=0.954460  Lz0=2.219931  shell=3.713e-02
# iter=  10 time=   24.8s total=1.510e+00 W=8.85e-01 R=2.84e-03 F=3.47e-01 BC=2.17e+00 r_H=2.0100 |g|=7.81e+00
# r0=9.428261  theta0=0.959142  E0=1.017487  Lz0=2.135533  shell=6.214e-04
# iter=  20 time=   27.3s total=5.050e-01 W=3.44e-01 R=8.16e-04 F=2.64e-01 BC=1.28e+00 r_H=1.0000 |g|=1.29e+00
# r0=9.567095  theta0=0.978204  E0=1.044380  Lz0=2.077441  shell=4.945e-03
# iter=  30 time=   27.5s total=3.773e-01 W=2.71e-01 R=1.95e-03 F=2.10e-01 BC=3.49e-01 r_H=1.0000 |g|=2.22e+00
# r0=9.528704  theta0=0.976253  E0=1.007641  Lz0=2.083006  shell=7.833e-06
# iter=  40 time=   27.8s total=2.669e-01 W=2.45e-01 R=6.57e-03 F=1.78e-01 BC=2.34e-03 r_H=1.0646 |g|=3.48e-01
#
# Adam 2/3: [0:50], 40 iterations
# r0=9.401651  theta0=0.964437  E0=0.988563  Lz0=2.101417  shell=2.028e-04
# iter=  50 time=   52.5s total=7.041e-01 W=6.88e-01 R=7.31e-03 F=1.04e-01 BC=2.86e-03 r_H=1.2391 |g|=2.66e+00
# r0=9.252311  theta0=0.963093  E0=0.991825  Lz0=2.056679  shell=3.641e-03
# iter=  60 time=   53.1s total=2.960e-01 W=2.47e-01 R=1.20e-02 F=5.71e-02 BC=5.10e-03 r_H=1.3537 |g|=3.33e+00
# r0=9.239898  theta0=0.940031  E0=0.958950  Lz0=2.082945  shell=4.325e-04
# iter=  70 time=   53.5s total=1.611e-01 W=1.50e-01 R=5.78e-03 F=3.74e-02 BC=2.93e-03 r_H=1.3578 |g|=6.50e-01
# r0=9.141973  theta0=0.911980  E0=0.962565  Lz0=2.107210  shell=6.964e-05
# iter=  80 time=   54.0s total=1.099e-01 W=1.05e-01 R=3.77e-03 F=2.69e-02 BC=9.46e-04 r_H=1.3314 |g|=2.74e-01
#
# Adam 3/3: [0:100], 35 iterations
# r0=9.024940  theta0=0.873818  E0=0.962166  Lz0=2.155129  shell=3.132e-04
# iter=  90 time=   76.8s total=8.095e-02 W=7.53e-02 R=2.59e-03 F=1.24e-02 BC=3.91e-05 r_H=1.2876 |g|=2.03e+00
# r0=8.962145  theta0=0.859436  E0=0.967142  Lz0=2.172184  shell=3.213e-05
# iter= 100 time=   77.8s total=8.503e-02 W=8.25e-02 R=2.03e-03 F=1.17e-02 BC=1.25e-05 r_H=1.3025 |g|=3.63e+00
# r0=8.932734  theta0=0.846090  E0=0.967431  Lz0=2.196482  shell=1.643e-04
# iter= 110 time=   78.8s total=8.808e-02 W=8.50e-02 R=1.07e-03 F=9.33e-03 BC=2.17e-05 r_H=1.3117 |g|=3.38e+00
# r0=8.911945  theta0=0.839175  E0=0.969028  Lz0=2.207828  shell=4.763e-05
# iter= 120 time=   79.8s total=5.739e-02 W=5.54e-02 R=1.23e-03 F=8.36e-03 BC=2.47e-04 r_H=1.3442 |g|=2.09e+00
# Adam complete: 120 iterations

# %% [markdown]
# ## Float64 BFGS / SSBroyden2 — same continuation schedule

# %%
# Original handoff precision. Note: consumer GPUs have weak float64 throughput.
params = tree_util.tree_map(lambda x: x.astype(jnp.float64), params)
t_full = t_full.astype(jnp.float64)
trajectory_gate, (hp_gate, hc_gate) = exact_kerr_gate(t_full)
hp_full = hp_gate[None, :]
hc_full = hc_gate[None, :]
LOSS_WEIGHTS = LOSS_WEIGHTS.astype(jnp.float64)

try:
    import _optimize as ssbroyden_patch
    import scipy.optimize._minimize as scipy_dispatch
    import scipy.optimize._optimize as scipy_internal
    scipy_internal._minimize_bfgs = ssbroyden_patch._minimize_bfgs
    scipy_dispatch._minimize_bfgs = ssbroyden_patch._minimize_bfgs
    USE_SSBROYDEN2 = True
    print("BFGS inverse-Hessian update: SSBroyden2")
except (ImportError, AttributeError) as exc:
    USE_SSBROYDEN2 = False
    print("SSBroyden2 patch unavailable; using stock SciPy BFGS:", exc)

LAST_GOOD = {"x": None, "f": None}
BAD_EVALS = {"n": 0, "last": ""}


def run_bfgs_stage(window, maxiter, params, weights):
    t_window = t_full[:window]
    hp_window = hp_full[:, :window]
    hc_window = hc_full[:, :window]
    x0, unravel = ravel_pytree(params)
    x0 = np.asarray(jax.device_get(x0), dtype=np.float64)

    def loss_and_gradient(x, reject_bad=True, record=True):
        try:
            trial = unravel(jnp.asarray(x, dtype=jnp.float64))
            (value_aux, grads) = loss_value_and_grad(
                trial, t_window, hp_window, hc_window, weights
            )
            value, (components, _, shell, u0_fit) = value_aux
            grad, _ = ravel_pytree(grads)
            value_np = float(jax.device_get(value))
            grad_np = np.asarray(jax.device_get(grad), dtype=np.float64)
            if not np.isfinite(value_np) or not np.isfinite(grad_np).all():
                raise FloatingPointError("non-finite loss/gradient")
            if record:
                values = np.asarray(jax.device_get(components))
                histories["total"].append(value_np)
                for name, raw, weight in zip(
                    ("waveform", "ricci", "frequency", "boundary"), values, np.asarray(weights)
                ):
                    histories[name].append(float(weight * raw))
                histories["mass_shell"].append(float(P_MASS_SHELL * shell))
            LAST_GOOD.update(x=np.asarray(x).copy(), f=value_np)
            return value_np, grad_np
        except (FloatingPointError, RuntimeError) as exc:
            if not reject_bad:
                raise
            BAD_EVALS["n"] += 1
            BAD_EVALS["last"] = repr(exc)[:200]
            xv = np.asarray(x, dtype=np.float64)
            xref = LAST_GOOD["x"] if LAST_GOOD["x"] is not None else xv
            fref = LAST_GOOD["f"] if LAST_GOOD["f"] is not None else 1.0
            delta = xv - xref
            return float(fref * (1.0 + delta @ delta)), 2.0 * fref * delta

    gate_loss, gate_grad = loss_and_gradient(x0, reject_bad=False, record=False)
    print(f"[0:{window}] gate loss={gate_loss:.3e} |grad|={np.linalg.norm(gate_grad):.3e}")
    assert np.isfinite(gate_loss) and np.isfinite(gate_grad).all()
    assert np.linalg.norm(gate_grad) > 1e-12

    stage_start = time.time()

    def callback(intermediate_result):
        # The parameter name asks modern SciPy for an OptimizeResult;
        # the ndarray fallback keeps compatibility with older patches.
        accepted_x = (intermediate_result.x if hasattr(intermediate_result, "x")
                      else np.asarray(intermediate_result))
        accepted_fun = (float(intermediate_result.fun) if hasattr(intermediate_result, "fun")
                        else LAST_GOOD["f"])
        LAST_GOOD.update(x=np.asarray(accepted_x).copy(), f=accepted_fun)
        accepted_params = unravel(jnp.asarray(accepted_x, dtype=jnp.float64))
        record_monitor(accepted_params)
        save_checkpoint(CHECKPOINT_PATH, accepted_params, len(schedule) - 1,
                        schedule[-1][1] - 1, n, histories)
        print(f"BFGS accepted loss={accepted_fun:.3e} elapsed={(time.time()-stage_start):.1f}s")

    options = {"maxiter": maxiter, "gtol": 1e-6, "disp": True}
    if USE_SSBROYDEN2:
        options.update(method_bfgs="SSBroyden2", initial_scale=True)
    result = minimize(loss_and_gradient, x0, jac=True, method="BFGS",
                      callback=callback, options=options)
    final_params = unravel(jnp.asarray(result.x, dtype=jnp.float64))
    save_checkpoint(SAVE_DIR / f"{RUN_ID}_w{window}.npz", final_params,
                    len(schedule) - 1, schedule[-1][1] - 1, n, histories)
    print(f"[0:{window}] done loss={result.fun:.3e} iters={result.nit} "
          f"evals={result.nfev} bad={BAD_EVALS['n']} {BAD_EVALS['last']}")
    return final_params, result


bfgs_start = time.time()
for window, maxiter in [
    (200, 30),
    (400, 30),
    (600, 30),
    (800, 50),
]:
    params, result = run_bfgs_stage(
        window, maxiter, params, LOSS_WEIGHTS
    )

LOSS_WEIGHTS = LOSS_WEIGHTS.at[1].set(2.0)

for window, maxiter in [
    (900, 30),
    (950, 30),
    (1000, 1500),
]:
    params, result = run_bfgs_stage(
        window, maxiter, params, LOSS_WEIGHTS
    )

print("BFGS minutes:", (time.time() - bfgs_start) / 60.0)
print("final loss:", result.fun, "success:", result.success, result.message)
# Out:
# BFGS inverse-Hessian update: SSBroyden2
# [0:200] gate loss=7.062e-02 |grad|=1.292e+01
# BFGS accepted loss=5.419e-02 elapsed=1.2s
# BFGS accepted loss=5.393e-02 elapsed=1.5s
# BFGS accepted loss=5.387e-02 elapsed=1.9s
# BFGS accepted loss=5.142e-02 elapsed=2.7s
# BFGS accepted loss=4.707e-02 elapsed=2.9s
# BFGS accepted loss=4.166e-02 elapsed=3.2s
# BFGS accepted loss=4.104e-02 elapsed=3.4s
# BFGS accepted loss=4.070e-02 elapsed=3.7s
# BFGS accepted loss=4.014e-02 elapsed=3.9s
# BFGS accepted loss=3.941e-02 elapsed=4.2s
# BFGS accepted loss=3.844e-02 elapsed=4.4s
# BFGS accepted loss=3.680e-02 elapsed=4.7s
# BFGS accepted loss=3.482e-02 elapsed=4.9s
# BFGS accepted loss=3.378e-02 elapsed=5.2s
# BFGS accepted loss=3.271e-02 elapsed=5.4s
# BFGS accepted loss=3.220e-02 elapsed=5.9s
# BFGS accepted loss=2.758e-02 elapsed=6.4s
# BFGS accepted loss=2.266e-02 elapsed=6.7s
# BFGS accepted loss=2.149e-02 elapsed=7.2s
# BFGS accepted loss=2.027e-02 elapsed=7.4s
# BFGS accepted loss=1.881e-02 elapsed=7.7s
# BFGS accepted loss=1.672e-02 elapsed=8.0s
# BFGS accepted loss=1.377e-02 elapsed=8.2s
# BFGS accepted loss=1.244e-02 elapsed=8.5s
# BFGS accepted loss=1.104e-02 elapsed=8.7s
# BFGS accepted loss=1.101e-02 elapsed=9.0s
# BFGS accepted loss=1.072e-02 elapsed=9.5s
# BFGS accepted loss=8.656e-03 elapsed=10.0s
# BFGS accepted loss=7.789e-03 elapsed=10.2s
# BFGS accepted loss=6.898e-03 elapsed=10.5s
#          Current function value: 0.006898
#          Iterations: 30
#          Function evaluations: 42
#          Gradient evaluations: 42
# [0:200] done loss=6.898e-03 iters=30 evals=42 bad=0
# /usr/local/lib/python3.12/dist-packages/scipy/optimize/_minimize.py:779: OptimizeWarning: Maximum number of iterations has been exceeded.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
# [0:400] gate loss=3.624e-01 |grad|=1.036e+02
# BFGS accepted loss=1.329e-01 elapsed=2.9s
# BFGS accepted loss=1.306e-01 elapsed=3.4s
# BFGS accepted loss=1.305e-01 elapsed=3.8s
# BFGS accepted loss=1.134e-01 elapsed=5.8s
# BFGS accepted loss=8.871e-02 elapsed=6.3s
# BFGS accepted loss=8.170e-02 elapsed=6.8s
# BFGS accepted loss=8.113e-02 elapsed=7.3s
# BFGS accepted loss=7.606e-02 elapsed=8.2s
# BFGS accepted loss=6.869e-02 elapsed=8.7s
# BFGS accepted loss=6.214e-02 elapsed=9.2s
# BFGS accepted loss=5.579e-02 elapsed=9.7s
# BFGS accepted loss=5.375e-02 elapsed=10.2s
# BFGS accepted loss=5.038e-02 elapsed=10.7s
# BFGS accepted loss=4.718e-02 elapsed=11.2s
# BFGS accepted loss=4.193e-02 elapsed=11.6s
# BFGS accepted loss=3.998e-02 elapsed=12.6s
# BFGS accepted loss=3.653e-02 elapsed=13.1s
# BFGS accepted loss=3.092e-02 elapsed=13.6s
# BFGS accepted loss=2.605e-02 elapsed=14.1s
# BFGS accepted loss=2.390e-02 elapsed=15.0s
# BFGS accepted loss=2.241e-02 elapsed=15.5s
# BFGS accepted loss=2.053e-02 elapsed=16.0s
# BFGS accepted loss=1.862e-02 elapsed=16.5s
# BFGS accepted loss=1.765e-02 elapsed=17.5s
# BFGS accepted loss=1.627e-02 elapsed=17.9s
# BFGS accepted loss=1.421e-02 elapsed=18.4s
# BFGS accepted loss=1.168e-02 elapsed=18.9s
# BFGS accepted loss=1.104e-02 elapsed=19.9s
# BFGS accepted loss=1.029e-02 elapsed=20.4s
# BFGS accepted loss=9.121e-03 elapsed=20.9s
#          Current function value: 0.009121
#          Iterations: 30
#          Function evaluations: 43
#          Gradient evaluations: 43
# [0:400] done loss=9.121e-03 iters=30 evals=43 bad=0
# [0:600] gate loss=9.212e-02 |grad|=1.020e+02
# BFGS accepted loss=4.474e-02 elapsed=5.0s
# BFGS accepted loss=4.470e-02 elapsed=6.4s
# BFGS accepted loss=3.903e-02 elapsed=9.3s
# BFGS accepted loss=3.011e-02 elapsed=10.0s
# BFGS accepted loss=2.617e-02 elapsed=10.7s
# BFGS accepted loss=2.608e-02 elapsed=11.5s
# BFGS accepted loss=2.597e-02 elapsed=12.9s
# BFGS accepted loss=2.508e-02 elapsed=14.3s
# BFGS accepted loss=2.491e-02 elapsed=15.8s
# BFGS accepted loss=2.460e-02 elapsed=16.5s
# BFGS accepted loss=2.404e-02 elapsed=17.2s
# BFGS accepted loss=2.322e-02 elapsed=17.9s
# BFGS accepted loss=2.266e-02 elapsed=18.6s
# BFGS accepted loss=2.200e-02 elapsed=19.4s
# BFGS accepted loss=2.077e-02 elapsed=20.1s
# BFGS accepted loss=1.930e-02 elapsed=20.8s
# BFGS accepted loss=1.745e-02 elapsed=21.5s
# BFGS accepted loss=1.709e-02 elapsed=23.0s
# BFGS accepted loss=1.669e-02 elapsed=23.7s
# BFGS accepted loss=1.635e-02 elapsed=24.5s
# BFGS accepted loss=1.620e-02 elapsed=25.2s
# BFGS accepted loss=1.597e-02 elapsed=25.9s
# BFGS accepted loss=1.561e-02 elapsed=26.6s
# BFGS accepted loss=1.503e-02 elapsed=27.3s
# BFGS accepted loss=1.463e-02 elapsed=28.8s
# BFGS accepted loss=1.409e-02 elapsed=29.5s
# BFGS accepted loss=1.375e-02 elapsed=30.9s
# BFGS accepted loss=1.332e-02 elapsed=31.6s
# BFGS accepted loss=1.323e-02 elapsed=32.3s
# BFGS accepted loss=1.307e-02 elapsed=33.1s
#          Current function value: 0.013071
#          Iterations: 30
#          Function evaluations: 46
#          Gradient evaluations: 46
# [0:600] done loss=1.307e-02 iters=30 evals=46 bad=0
# [0:800] gate loss=2.231e-01 |grad|=2.601e+02
# BFGS accepted loss=1.198e-01 elapsed=6.6s
# BFGS accepted loss=1.158e-01 elapsed=7.5s
# BFGS accepted loss=1.079e-01 elapsed=10.4s
# BFGS accepted loss=9.288e-02 elapsed=11.4s
# BFGS accepted loss=6.629e-02 elapsed=12.4s
# BFGS accepted loss=3.141e-02 elapsed=13.3s
# BFGS accepted loss=2.697e-02 elapsed=14.3s
# BFGS accepted loss=2.673e-02 elapsed=15.2s
# BFGS accepted loss=2.455e-02 elapsed=17.1s
# BFGS accepted loss=2.250e-02 elapsed=18.1s
# BFGS accepted loss=2.179e-02 elapsed=20.0s
# BFGS accepted loss=2.087e-02 elapsed=20.9s
# BFGS accepted loss=2.077e-02 elapsed=21.9s
# BFGS accepted loss=2.071e-02 elapsed=22.8s
# BFGS accepted loss=2.060e-02 elapsed=23.8s
# BFGS accepted loss=1.975e-02 elapsed=25.7s
# BFGS accepted loss=1.960e-02 elapsed=27.6s
# BFGS accepted loss=1.931e-02 elapsed=28.6s
# BFGS accepted loss=1.908e-02 elapsed=29.5s
# BFGS accepted loss=1.877e-02 elapsed=30.5s
# BFGS accepted loss=1.865e-02 elapsed=31.4s
# BFGS accepted loss=1.852e-02 elapsed=32.4s
# BFGS accepted loss=1.844e-02 elapsed=33.3s
# BFGS accepted loss=1.833e-02 elapsed=34.3s
# BFGS accepted loss=1.816e-02 elapsed=35.2s
# BFGS accepted loss=1.786e-02 elapsed=36.2s
# BFGS accepted loss=1.761e-02 elapsed=37.2s
# BFGS accepted loss=1.721e-02 elapsed=38.1s
# BFGS accepted loss=1.698e-02 elapsed=40.0s
# BFGS accepted loss=1.687e-02 elapsed=41.9s
# BFGS accepted loss=1.671e-02 elapsed=42.9s
# BFGS accepted loss=1.642e-02 elapsed=43.8s
# BFGS accepted loss=1.595e-02 elapsed=44.8s
# BFGS accepted loss=1.537e-02 elapsed=45.7s
# BFGS accepted loss=1.499e-02 elapsed=46.7s
# BFGS accepted loss=1.438e-02 elapsed=47.6s
# BFGS accepted loss=1.363e-02 elapsed=48.6s
# BFGS accepted loss=1.312e-02 elapsed=50.5s
# BFGS accepted loss=1.250e-02 elapsed=51.4s
# BFGS accepted loss=1.162e-02 elapsed=52.4s
# BFGS accepted loss=1.111e-02 elapsed=54.3s
# BFGS accepted loss=1.044e-02 elapsed=55.3s
# BFGS accepted loss=1.022e-02 elapsed=56.2s
# BFGS accepted loss=1.009e-02 elapsed=57.2s
# BFGS accepted loss=9.891e-03 elapsed=58.1s
# BFGS accepted loss=9.621e-03 elapsed=59.1s
# BFGS accepted loss=9.455e-03 elapsed=61.0s
# BFGS accepted loss=9.146e-03 elapsed=61.9s
# BFGS accepted loss=8.833e-03 elapsed=62.9s
# BFGS accepted loss=8.354e-03 elapsed=63.9s
#          Current function value: 0.008354
#          Iterations: 50
#          Function evaluations: 67
#          Gradient evaluations: 67
# [0:800] done loss=8.354e-03 iters=50 evals=67 bad=0
# [0:900] gate loss=2.834e-02 |grad|=3.672e+01
# BFGS accepted loss=2.697e-02 elapsed=15.9s
# BFGS accepted loss=2.693e-02 elapsed=19.1s
# BFGS accepted loss=2.658e-02 elapsed=21.2s
# BFGS accepted loss=2.594e-02 elapsed=22.3s
# BFGS accepted loss=2.492e-02 elapsed=23.4s
# BFGS accepted loss=2.364e-02 elapsed=24.4s
# BFGS accepted loss=2.223e-02 elapsed=25.5s
# BFGS accepted loss=2.125e-02 elapsed=26.6s
# BFGS accepted loss=2.091e-02 elapsed=27.7s
# BFGS accepted loss=2.080e-02 elapsed=29.8s
# BFGS accepted loss=2.012e-02 elapsed=31.9s
# BFGS accepted loss=1.971e-02 elapsed=33.0s
# BFGS accepted loss=1.928e-02 elapsed=34.1s
# BFGS accepted loss=1.911e-02 elapsed=36.2s
# BFGS accepted loss=1.897e-02 elapsed=37.3s
# BFGS accepted loss=1.874e-02 elapsed=38.4s
# BFGS accepted loss=1.842e-02 elapsed=39.5s
# BFGS accepted loss=1.821e-02 elapsed=40.5s
# BFGS accepted loss=1.812e-02 elapsed=41.6s
# BFGS accepted loss=1.801e-02 elapsed=42.7s
#          Current function value: 0.018011
#          Iterations: 20
#          Function evaluations: 40
#          Gradient evaluations: 29
# [0:900] done loss=1.801e-02 iters=20 evals=40 bad=0
# /usr/local/lib/python3.12/dist-packages/scipy/optimize/_minimize.py:779: OptimizeWarning: Maximum number of iterations has been exceeded.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
# [0:950] gate loss=3.677e-02 |grad|=2.566e+01
# BFGS accepted loss=3.603e-02 elapsed=6.8s
# BFGS accepted loss=3.543e-02 elapsed=9.0s
# BFGS accepted loss=3.428e-02 elapsed=10.1s
# BFGS accepted loss=3.220e-02 elapsed=11.3s
# BFGS accepted loss=2.904e-02 elapsed=12.4s
# BFGS accepted loss=2.799e-02 elapsed=13.6s
# BFGS accepted loss=2.777e-02 elapsed=15.8s
# BFGS accepted loss=2.734e-02 elapsed=17.0s
# BFGS accepted loss=2.689e-02 elapsed=18.1s
# BFGS accepted loss=2.611e-02 elapsed=19.3s
# BFGS accepted loss=2.523e-02 elapsed=20.4s
# BFGS accepted loss=2.507e-02 elapsed=21.5s
# BFGS accepted loss=2.486e-02 elapsed=22.7s
# BFGS accepted loss=2.449e-02 elapsed=23.8s
# BFGS accepted loss=2.432e-02 elapsed=26.1s
# BFGS accepted loss=2.402e-02 elapsed=27.2s
# BFGS accepted loss=2.391e-02 elapsed=29.5s
# BFGS accepted loss=2.371e-02 elapsed=30.6s
# BFGS accepted loss=2.336e-02 elapsed=31.7s
# BFGS accepted loss=2.283e-02 elapsed=32.9s
#          Current function value: 0.022832
#          Iterations: 20
#          Function evaluations: 29
#          Gradient evaluations: 29
# [0:950] done loss=2.283e-02 iters=20 evals=29 bad=0
# [0:975] gate loss=3.367e-02 |grad|=2.058e+00
# /usr/local/lib/python3.12/dist-packages/scipy/optimize/_minimize.py:779: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 0.033674
#          Iterations: 0
#          Function evaluations: 16
#          Gradient evaluations: 4
# [0:975] done loss=3.367e-02 iters=0 evals=16 bad=0
# [0:990] gate loss=3.367e-02 |grad|=5.608e+00
# /usr/local/lib/python3.12/dist-packages/scipy/optimize/_minimize.py:779: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 0.033669
#          Iterations: 0
#          Function evaluations: 16
#          Gradient evaluations: 4
# [0:990] done loss=3.367e-02 iters=0 evals=16 bad=0
# [0:1000] gate loss=3.076e-02 |grad|=3.351e+01
# BFGS accepted loss=3.005e-02 elapsed=8.3s
# BFGS accepted loss=3.005e-02 elapsed=9.5s
# BFGS accepted loss=3.005e-02 elapsed=10.7s
# BFGS accepted loss=2.974e-02 elapsed=15.4s
# BFGS accepted loss=2.928e-02 elapsed=16.6s
# BFGS accepted loss=2.907e-02 elapsed=17.8s
# BFGS accepted loss=2.894e-02 elapsed=19.0s
# BFGS accepted loss=2.871e-02 elapsed=20.2s
# BFGS accepted loss=2.833e-02 elapsed=21.4s
# BFGS accepted loss=2.819e-02 elapsed=23.8s
# BFGS accepted loss=2.797e-02 elapsed=25.0s
# BFGS accepted loss=2.767e-02 elapsed=26.2s
# BFGS accepted loss=2.715e-02 elapsed=27.4s
# BFGS accepted loss=2.658e-02 elapsed=28.6s
# BFGS accepted loss=2.651e-02 elapsed=29.7s
# BFGS accepted loss=2.650e-02 elapsed=32.1s
# BFGS accepted loss=2.649e-02 elapsed=33.3s
# BFGS accepted loss=2.648e-02 elapsed=34.5s
# BFGS accepted loss=2.643e-02 elapsed=36.9s
# BFGS accepted loss=2.593e-02 elapsed=39.3s
# BFGS accepted loss=2.546e-02 elapsed=40.5s
# BFGS accepted loss=2.534e-02 elapsed=41.7s
# BFGS accepted loss=2.523e-02 elapsed=42.9s
# BFGS accepted loss=2.515e-02 elapsed=44.0s
# BFGS accepted loss=2.509e-02 elapsed=45.2s
# BFGS accepted loss=2.501e-02 elapsed=46.4s
# BFGS accepted loss=2.488e-02 elapsed=47.6s
# BFGS accepted loss=2.465e-02 elapsed=48.8s
# BFGS accepted loss=2.431e-02 elapsed=50.0s
# BFGS accepted loss=2.411e-02 elapsed=52.4s
# BFGS accepted loss=2.380e-02 elapsed=53.6s
# BFGS accepted loss=2.335e-02 elapsed=54.8s
# BFGS accepted loss=2.311e-02 elapsed=56.0s
# BFGS accepted loss=2.298e-02 elapsed=58.4s
# BFGS accepted loss=2.276e-02 elapsed=59.5s
# BFGS accepted loss=2.242e-02 elapsed=60.7s
# BFGS accepted loss=2.191e-02 elapsed=61.9s
# BFGS accepted loss=2.161e-02 elapsed=63.1s
# BFGS accepted loss=2.115e-02 elapsed=64.3s
# BFGS accepted loss=2.082e-02 elapsed=66.7s
# BFGS accepted loss=2.033e-02 elapsed=67.9s
# BFGS accepted loss=1.954e-02 elapsed=69.1s
# BFGS accepted loss=1.866e-02 elapsed=70.3s
# BFGS accepted loss=1.833e-02 elapsed=72.7s
# BFGS accepted loss=1.787e-02 elapsed=73.8s
# BFGS accepted loss=1.739e-02 elapsed=75.0s
# BFGS accepted loss=1.686e-02 elapsed=76.2s
# BFGS accepted loss=1.622e-02 elapsed=77.4s
# BFGS accepted loss=1.545e-02 elapsed=78.6s
# BFGS accepted loss=1.491e-02 elapsed=79.8s
# BFGS accepted loss=1.427e-02 elapsed=81.0s
# BFGS accepted loss=1.402e-02 elapsed=83.4s
# BFGS accepted loss=1.387e-02 elapsed=85.8s
# BFGS accepted loss=1.362e-02 elapsed=87.0s
# BFGS accepted loss=1.318e-02 elapsed=88.2s
# BFGS accepted loss=1.288e-02 elapsed=90.6s
# BFGS accepted loss=1.236e-02 elapsed=91.8s
# BFGS accepted loss=1.182e-02 elapsed=92.9s
# BFGS accepted loss=1.125e-02 elapsed=94.2s
# BFGS accepted loss=1.075e-02 elapsed=95.4s
# BFGS accepted loss=1.033e-02 elapsed=96.6s
# BFGS accepted loss=1.004e-02 elapsed=97.7s
# BFGS accepted loss=9.566e-03 elapsed=98.9s
# BFGS accepted loss=9.486e-03 elapsed=101.3s
# BFGS accepted loss=8.941e-03 elapsed=103.7s
# BFGS accepted loss=8.711e-03 elapsed=104.9s
# BFGS accepted loss=8.397e-03 elapsed=106.1s
# BFGS accepted loss=8.338e-03 elapsed=108.5s
# BFGS accepted loss=8.241e-03 elapsed=109.7s
# BFGS accepted loss=8.101e-03 elapsed=110.9s
# BFGS accepted loss=8.059e-03 elapsed=112.1s
# BFGS accepted loss=7.993e-03 elapsed=113.3s
# BFGS accepted loss=7.896e-03 elapsed=114.5s
# BFGS accepted loss=7.754e-03 elapsed=115.7s
# BFGS accepted loss=7.714e-03 elapsed=116.9s
# BFGS accepted loss=7.551e-03 elapsed=120.4s
# BFGS accepted loss=7.485e-03 elapsed=122.8s
# BFGS accepted loss=7.362e-03 elapsed=124.0s
# BFGS accepted loss=7.128e-03 elapsed=125.2s
# BFGS accepted loss=6.977e-03 elapsed=127.6s
# BFGS accepted loss=6.019e-03 elapsed=130.0s
# BFGS accepted loss=5.773e-03 elapsed=131.2s
# BFGS accepted loss=5.469e-03 elapsed=132.3s
# BFGS accepted loss=5.031e-03 elapsed=133.5s
# BFGS accepted loss=4.877e-03 elapsed=135.9s
# BFGS accepted loss=4.723e-03 elapsed=137.1s
# BFGS accepted loss=4.616e-03 elapsed=138.3s
# BFGS accepted loss=4.583e-03 elapsed=140.7s
# BFGS accepted loss=4.531e-03 elapsed=141.9s
# BFGS accepted loss=4.454e-03 elapsed=143.1s
# BFGS accepted loss=4.358e-03 elapsed=144.3s
# BFGS accepted loss=4.267e-03 elapsed=145.5s
# BFGS accepted loss=4.222e-03 elapsed=146.7s
# BFGS accepted loss=4.147e-03 elapsed=147.9s
# BFGS accepted loss=4.051e-03 elapsed=149.1s
# BFGS accepted loss=3.988e-03 elapsed=150.3s
# BFGS accepted loss=3.889e-03 elapsed=151.5s
# BFGS accepted loss=3.760e-03 elapsed=152.7s
# BFGS accepted loss=3.621e-03 elapsed=153.9s
# BFGS accepted loss=3.490e-03 elapsed=155.1s
# BFGS accepted loss=3.413e-03 elapsed=157.5s
# BFGS accepted loss=3.310e-03 elapsed=158.7s
# BFGS accepted loss=3.165e-03 elapsed=159.9s
# BFGS accepted loss=3.086e-03 elapsed=161.0s
# BFGS accepted loss=2.949e-03 elapsed=162.2s
# BFGS accepted loss=2.732e-03 elapsed=163.4s
# BFGS accepted loss=2.571e-03 elapsed=164.7s
# BFGS accepted loss=2.476e-03 elapsed=167.0s
# BFGS accepted loss=2.338e-03 elapsed=168.2s
# BFGS accepted loss=2.205e-03 elapsed=169.4s
# BFGS accepted loss=2.128e-03 elapsed=171.8s
# BFGS accepted loss=2.010e-03 elapsed=173.0s
# BFGS accepted loss=1.887e-03 elapsed=174.2s
# BFGS accepted loss=1.825e-03 elapsed=176.6s
# BFGS accepted loss=1.801e-03 elapsed=178.9s
# BFGS accepted loss=1.769e-03 elapsed=180.1s
# BFGS accepted loss=1.727e-03 elapsed=181.3s
# BFGS accepted loss=1.708e-03 elapsed=182.5s
# BFGS accepted loss=1.676e-03 elapsed=183.7s
# BFGS accepted loss=1.646e-03 elapsed=184.9s
# BFGS accepted loss=1.618e-03 elapsed=186.1s
# BFGS accepted loss=1.610e-03 elapsed=188.5s
# BFGS accepted loss=1.598e-03 elapsed=189.7s
# BFGS accepted loss=1.577e-03 elapsed=190.9s
# BFGS accepted loss=1.543e-03 elapsed=192.1s
# BFGS accepted loss=1.515e-03 elapsed=193.3s
# BFGS accepted loss=1.480e-03 elapsed=194.5s
# BFGS accepted loss=1.459e-03 elapsed=195.7s
# BFGS accepted loss=1.428e-03 elapsed=196.9s
# BFGS accepted loss=1.404e-03 elapsed=199.2s
# BFGS accepted loss=1.388e-03 elapsed=200.4s
# BFGS accepted loss=1.376e-03 elapsed=201.6s
# BFGS accepted loss=1.358e-03 elapsed=202.8s
# BFGS accepted loss=1.338e-03 elapsed=204.0s
# BFGS accepted loss=1.323e-03 elapsed=205.2s
# BFGS accepted loss=1.306e-03 elapsed=206.4s
# BFGS accepted loss=1.286e-03 elapsed=207.6s
# BFGS accepted loss=1.254e-03 elapsed=208.8s
# BFGS accepted loss=1.228e-03 elapsed=211.2s
# BFGS accepted loss=1.200e-03 elapsed=212.4s
# BFGS accepted loss=1.179e-03 elapsed=213.6s
# BFGS accepted loss=1.152e-03 elapsed=214.8s
# BFGS accepted loss=1.137e-03 elapsed=217.1s
# BFGS accepted loss=1.116e-03 elapsed=218.4s
# BFGS accepted loss=1.089e-03 elapsed=219.6s
# BFGS accepted loss=1.080e-03 elapsed=220.7s
# BFGS accepted loss=1.064e-03 elapsed=221.9s
# BFGS accepted loss=1.054e-03 elapsed=223.1s
# BFGS accepted loss=1.038e-03 elapsed=224.3s
# BFGS accepted loss=1.013e-03 elapsed=225.5s
# BFGS accepted loss=9.996e-04 elapsed=226.7s
# BFGS accepted loss=9.780e-04 elapsed=227.9s
# BFGS accepted loss=9.635e-04 elapsed=230.3s
# BFGS accepted loss=9.435e-04 elapsed=231.5s
# BFGS accepted loss=9.224e-04 elapsed=232.7s
# BFGS accepted loss=9.100e-04 elapsed=235.1s
# BFGS accepted loss=9.023e-04 elapsed=237.5s
# BFGS accepted loss=8.907e-04 elapsed=238.7s
# BFGS accepted loss=8.726e-04 elapsed=239.8s
# BFGS accepted loss=8.518e-04 elapsed=241.0s
# BFGS accepted loss=8.395e-04 elapsed=243.4s
# BFGS accepted loss=8.230e-04 elapsed=244.6s
# BFGS accepted loss=7.978e-04 elapsed=245.8s
# BFGS accepted loss=7.769e-04 elapsed=247.0s
# BFGS accepted loss=7.512e-04 elapsed=248.2s
# BFGS accepted loss=7.361e-04 elapsed=249.4s
# BFGS accepted loss=7.128e-04 elapsed=250.6s
# BFGS accepted loss=6.896e-04 elapsed=251.8s
# BFGS accepted loss=6.854e-04 elapsed=253.0s
# BFGS accepted loss=6.779e-04 elapsed=254.2s
# BFGS accepted loss=6.645e-04 elapsed=255.4s
# BFGS accepted loss=6.500e-04 elapsed=256.6s
# BFGS accepted loss=6.389e-04 elapsed=257.8s
# BFGS accepted loss=6.364e-04 elapsed=259.0s
# BFGS accepted loss=6.322e-04 elapsed=260.2s
# BFGS accepted loss=6.246e-04 elapsed=261.4s
# BFGS accepted loss=6.142e-04 elapsed=262.6s
# BFGS accepted loss=6.091e-04 elapsed=263.8s
# BFGS accepted loss=6.012e-04 elapsed=265.0s
# BFGS accepted loss=5.888e-04 elapsed=266.2s
# BFGS accepted loss=5.747e-04 elapsed=267.4s
# BFGS accepted loss=5.613e-04 elapsed=268.6s
# BFGS accepted loss=5.433e-04 elapsed=269.8s
# BFGS accepted loss=5.302e-04 elapsed=272.1s
# BFGS accepted loss=5.171e-04 elapsed=273.3s
# BFGS accepted loss=5.048e-04 elapsed=274.5s
# BFGS accepted loss=5.001e-04 elapsed=275.7s
# BFGS accepted loss=4.920e-04 elapsed=276.9s
# BFGS accepted loss=4.784e-04 elapsed=278.1s
# BFGS accepted loss=4.599e-04 elapsed=279.3s
# BFGS accepted loss=4.492e-04 elapsed=281.7s
# BFGS accepted loss=4.356e-04 elapsed=282.9s
# BFGS accepted loss=4.203e-04 elapsed=284.1s
# BFGS accepted loss=4.150e-04 elapsed=286.5s
# BFGS accepted loss=4.057e-04 elapsed=287.7s
# BFGS accepted loss=3.916e-04 elapsed=288.9s
# BFGS accepted loss=3.741e-04 elapsed=290.1s
# BFGS accepted loss=3.647e-04 elapsed=292.4s
# BFGS accepted loss=3.617e-04 elapsed=293.7s
# BFGS accepted loss=3.563e-04 elapsed=294.9s
# BFGS accepted loss=3.465e-04 elapsed=296.0s
# BFGS accepted loss=3.312e-04 elapsed=297.2s
# BFGS accepted loss=3.246e-04 elapsed=298.4s
# BFGS accepted loss=3.140e-04 elapsed=299.6s
# BFGS accepted loss=3.091e-04 elapsed=300.8s
# BFGS accepted loss=3.006e-04 elapsed=302.0s
# BFGS accepted loss=2.891e-04 elapsed=303.2s
# BFGS accepted loss=2.833e-04 elapsed=305.6s
# BFGS accepted loss=2.749e-04 elapsed=306.8s
# BFGS accepted loss=2.700e-04 elapsed=309.2s
# BFGS accepted loss=2.625e-04 elapsed=310.3s
# BFGS accepted loss=2.573e-04 elapsed=311.5s
# BFGS accepted loss=2.494e-04 elapsed=312.7s
# BFGS accepted loss=2.426e-04 elapsed=313.9s
# BFGS accepted loss=2.388e-04 elapsed=316.3s
# BFGS accepted loss=2.346e-04 elapsed=317.5s
# BFGS accepted loss=2.295e-04 elapsed=318.7s
# BFGS accepted loss=2.259e-04 elapsed=319.9s
# BFGS accepted loss=2.220e-04 elapsed=321.1s
# BFGS accepted loss=2.193e-04 elapsed=322.3s
# BFGS accepted loss=2.150e-04 elapsed=323.5s
# BFGS accepted loss=2.094e-04 elapsed=324.7s
# BFGS accepted loss=2.060e-04 elapsed=325.9s
# BFGS accepted loss=2.024e-04 elapsed=327.1s
# BFGS accepted loss=1.981e-04 elapsed=328.3s
# BFGS accepted loss=1.964e-04 elapsed=329.5s
# BFGS accepted loss=1.941e-04 elapsed=330.7s
# BFGS accepted loss=1.916e-04 elapsed=331.8s
# BFGS accepted loss=1.893e-04 elapsed=333.0s
# BFGS accepted loss=1.873e-04 elapsed=334.2s
# BFGS accepted loss=1.847e-04 elapsed=335.4s
# BFGS accepted loss=1.822e-04 elapsed=336.6s
# BFGS accepted loss=1.811e-04 elapsed=337.8s
# BFGS accepted loss=1.797e-04 elapsed=339.0s
# BFGS accepted loss=1.780e-04 elapsed=340.2s
# BFGS accepted loss=1.769e-04 elapsed=341.4s
# BFGS accepted loss=1.761e-04 elapsed=342.6s
# BFGS accepted loss=1.749e-04 elapsed=343.8s
# BFGS accepted loss=1.736e-04 elapsed=345.0s
# BFGS accepted loss=1.723e-04 elapsed=346.2s
# BFGS accepted loss=1.716e-04 elapsed=348.6s
# BFGS accepted loss=1.704e-04 elapsed=349.8s
# BFGS accepted loss=1.688e-04 elapsed=351.0s
# BFGS accepted loss=1.672e-04 elapsed=352.2s
# BFGS accepted loss=1.662e-04 elapsed=354.5s
# BFGS accepted loss=1.652e-04 elapsed=355.7s
# BFGS accepted loss=1.647e-04 elapsed=356.9s
# BFGS accepted loss=1.638e-04 elapsed=358.1s
# BFGS accepted loss=1.625e-04 elapsed=359.3s
# BFGS accepted loss=1.606e-04 elapsed=360.5s
# BFGS accepted loss=1.582e-04 elapsed=361.7s
# BFGS accepted loss=1.569e-04 elapsed=364.1s
# BFGS accepted loss=1.560e-04 elapsed=365.3s
# BFGS accepted loss=1.547e-04 elapsed=366.5s
# BFGS accepted loss=1.535e-04 elapsed=367.7s
# BFGS accepted loss=1.522e-04 elapsed=368.9s
# BFGS accepted loss=1.511e-04 elapsed=370.1s
# BFGS accepted loss=1.493e-04 elapsed=371.3s
# BFGS accepted loss=1.473e-04 elapsed=372.5s
# BFGS accepted loss=1.461e-04 elapsed=374.8s
# BFGS accepted loss=1.448e-04 elapsed=376.0s
# BFGS accepted loss=1.441e-04 elapsed=378.4s
# BFGS accepted loss=1.430e-04 elapsed=379.6s
# BFGS accepted loss=1.414e-04 elapsed=380.8s
# BFGS accepted loss=1.401e-04 elapsed=382.0s
# BFGS accepted loss=1.382e-04 elapsed=383.2s
# BFGS accepted loss=1.361e-04 elapsed=384.4s
# BFGS accepted loss=1.350e-04 elapsed=385.6s
# BFGS accepted loss=1.332e-04 elapsed=386.8s
# BFGS accepted loss=1.319e-04 elapsed=388.0s
# BFGS accepted loss=1.297e-04 elapsed=389.2s
# BFGS accepted loss=1.267e-04 elapsed=390.3s
# BFGS accepted loss=1.243e-04 elapsed=391.5s
# BFGS accepted loss=1.237e-04 elapsed=392.7s
# BFGS accepted loss=1.227e-04 elapsed=393.9s
# BFGS accepted loss=1.209e-04 elapsed=395.1s
# BFGS accepted loss=1.188e-04 elapsed=396.3s
# BFGS accepted loss=1.178e-04 elapsed=398.7s
# BFGS accepted loss=1.161e-04 elapsed=399.9s
# BFGS accepted loss=1.144e-04 elapsed=401.1s
# BFGS accepted loss=1.131e-04 elapsed=402.3s
# BFGS accepted loss=1.116e-04 elapsed=403.5s
# BFGS accepted loss=1.109e-04 elapsed=404.7s
# BFGS accepted loss=1.100e-04 elapsed=405.9s
# BFGS accepted loss=1.084e-04 elapsed=407.1s
# BFGS accepted loss=1.078e-04 elapsed=409.5s
# BFGS accepted loss=1.069e-04 elapsed=410.7s
# BFGS accepted loss=1.057e-04 elapsed=411.9s
# BFGS accepted loss=1.044e-04 elapsed=413.1s
# BFGS accepted loss=1.036e-04 elapsed=415.4s
# BFGS accepted loss=1.031e-04 elapsed=417.8s
# BFGS accepted loss=1.025e-04 elapsed=419.0s
# BFGS accepted loss=1.017e-04 elapsed=420.2s
# BFGS accepted loss=1.008e-04 elapsed=421.4s
# BFGS accepted loss=9.947e-05 elapsed=422.6s
# BFGS accepted loss=9.815e-05 elapsed=423.8s
# BFGS accepted loss=9.739e-05 elapsed=426.2s
# BFGS accepted loss=9.694e-05 elapsed=428.5s
# BFGS accepted loss=9.624e-05 elapsed=429.7s
# BFGS accepted loss=9.525e-05 elapsed=430.9s
# BFGS accepted loss=9.474e-05 elapsed=432.1s
# BFGS accepted loss=9.404e-05 elapsed=433.3s
# BFGS accepted loss=9.313e-05 elapsed=434.5s
# BFGS accepted loss=9.185e-05 elapsed=435.7s
# BFGS accepted loss=9.149e-05 elapsed=436.9s
# BFGS accepted loss=9.091e-05 elapsed=438.1s
# BFGS accepted loss=8.988e-05 elapsed=439.3s
# BFGS accepted loss=8.832e-05 elapsed=440.5s
# BFGS accepted loss=8.634e-05 elapsed=441.7s
# BFGS accepted loss=8.529e-05 elapsed=442.9s
# BFGS accepted loss=8.406e-05 elapsed=444.1s
# BFGS accepted loss=8.340e-05 elapsed=445.3s
# BFGS accepted loss=8.225e-05 elapsed=446.5s
# BFGS accepted loss=8.053e-05 elapsed=447.7s
# BFGS accepted loss=7.979e-05 elapsed=448.8s
# BFGS accepted loss=7.869e-05 elapsed=450.0s
# BFGS accepted loss=7.781e-05 elapsed=451.2s
# BFGS accepted loss=7.701e-05 elapsed=452.4s
# BFGS accepted loss=7.613e-05 elapsed=453.6s
# BFGS accepted loss=7.569e-05 elapsed=456.0s
# BFGS accepted loss=7.510e-05 elapsed=457.2s
# BFGS accepted loss=7.461e-05 elapsed=458.4s
# BFGS accepted loss=7.397e-05 elapsed=459.6s
# BFGS accepted loss=7.331e-05 elapsed=460.8s
# BFGS accepted loss=7.299e-05 elapsed=462.0s
# BFGS accepted loss=7.250e-05 elapsed=463.2s
# BFGS accepted loss=7.208e-05 elapsed=464.4s
# BFGS accepted loss=7.153e-05 elapsed=465.6s
# BFGS accepted loss=7.094e-05 elapsed=466.8s
# BFGS accepted loss=7.031e-05 elapsed=468.0s
# BFGS accepted loss=6.989e-05 elapsed=469.2s
# BFGS accepted loss=6.919e-05 elapsed=470.4s
# BFGS accepted loss=6.824e-05 elapsed=471.6s
# BFGS accepted loss=6.745e-05 elapsed=472.8s
# BFGS accepted loss=6.648e-05 elapsed=473.9s
# BFGS accepted loss=6.575e-05 elapsed=475.1s
# BFGS accepted loss=6.461e-05 elapsed=476.3s
# BFGS accepted loss=6.382e-05 elapsed=477.5s
# BFGS accepted loss=6.297e-05 elapsed=478.7s
# BFGS accepted loss=6.216e-05 elapsed=479.9s
# BFGS accepted loss=6.129e-05 elapsed=481.1s
# BFGS accepted loss=6.010e-05 elapsed=482.3s
# BFGS accepted loss=5.924e-05 elapsed=483.5s
# BFGS accepted loss=5.892e-05 elapsed=484.7s
# BFGS accepted loss=5.835e-05 elapsed=485.9s
# BFGS accepted loss=5.743e-05 elapsed=487.1s
# BFGS accepted loss=5.683e-05 elapsed=488.3s
# BFGS accepted loss=5.610e-05 elapsed=489.5s
# BFGS accepted loss=5.527e-05 elapsed=490.7s
# BFGS accepted loss=5.485e-05 elapsed=491.9s
# BFGS accepted loss=5.448e-05 elapsed=493.1s
# BFGS accepted loss=5.401e-05 elapsed=494.3s
# BFGS accepted loss=5.347e-05 elapsed=495.5s
# BFGS accepted loss=5.297e-05 elapsed=496.7s
# BFGS accepted loss=5.247e-05 elapsed=497.9s
# BFGS accepted loss=5.178e-05 elapsed=499.1s
# BFGS accepted loss=5.090e-05 elapsed=500.3s
# BFGS accepted loss=5.036e-05 elapsed=501.5s
# BFGS accepted loss=4.969e-05 elapsed=502.7s
# BFGS accepted loss=4.895e-05 elapsed=503.9s
# BFGS accepted loss=4.852e-05 elapsed=505.1s
# BFGS accepted loss=4.788e-05 elapsed=506.3s
# BFGS accepted loss=4.700e-05 elapsed=507.5s
# BFGS accepted loss=4.646e-05 elapsed=508.7s
# BFGS accepted loss=4.589e-05 elapsed=509.9s
# BFGS accepted loss=4.530e-05 elapsed=511.1s
# BFGS accepted loss=4.446e-05 elapsed=512.2s
# BFGS accepted loss=4.349e-05 elapsed=513.4s
# BFGS accepted loss=4.295e-05 elapsed=515.8s
# BFGS accepted loss=4.241e-05 elapsed=517.0s
# BFGS accepted loss=4.179e-05 elapsed=518.2s
# BFGS accepted loss=4.120e-05 elapsed=519.4s
# BFGS accepted loss=4.062e-05 elapsed=520.6s
# BFGS accepted loss=3.980e-05 elapsed=521.8s
# BFGS accepted loss=3.927e-05 elapsed=524.2s
# BFGS accepted loss=3.877e-05 elapsed=525.4s
# BFGS accepted loss=3.828e-05 elapsed=526.6s
# BFGS accepted loss=3.803e-05 elapsed=527.7s
# BFGS accepted loss=3.764e-05 elapsed=528.9s
# BFGS accepted loss=3.714e-05 elapsed=530.1s
# BFGS accepted loss=3.654e-05 elapsed=531.3s
# BFGS accepted loss=3.588e-05 elapsed=532.5s
# BFGS accepted loss=3.559e-05 elapsed=533.7s
# BFGS accepted loss=3.515e-05 elapsed=534.9s
# BFGS accepted loss=3.456e-05 elapsed=536.1s
# BFGS accepted loss=3.426e-05 elapsed=538.5s
# BFGS accepted loss=3.387e-05 elapsed=539.7s
# BFGS accepted loss=3.376e-05 elapsed=540.9s
# BFGS accepted loss=3.356e-05 elapsed=542.1s
# BFGS accepted loss=3.319e-05 elapsed=543.3s
# BFGS accepted loss=3.264e-05 elapsed=544.5s
# BFGS accepted loss=3.228e-05 elapsed=546.8s
# BFGS accepted loss=3.210e-05 elapsed=548.0s
# BFGS accepted loss=3.183e-05 elapsed=549.2s
# BFGS accepted loss=3.144e-05 elapsed=550.4s
# BFGS accepted loss=3.115e-05 elapsed=551.6s
# BFGS accepted loss=3.085e-05 elapsed=552.8s
# BFGS accepted loss=3.070e-05 elapsed=554.0s
# BFGS accepted loss=3.049e-05 elapsed=555.2s
# BFGS accepted loss=3.030e-05 elapsed=556.4s
# BFGS accepted loss=3.009e-05 elapsed=557.6s
# BFGS accepted loss=2.985e-05 elapsed=558.8s
# BFGS accepted loss=2.971e-05 elapsed=561.2s
# BFGS accepted loss=2.951e-05 elapsed=562.4s
# BFGS accepted loss=2.928e-05 elapsed=563.6s
# BFGS accepted loss=2.908e-05 elapsed=564.8s
# BFGS accepted loss=2.889e-05 elapsed=566.0s
# BFGS accepted loss=2.863e-05 elapsed=567.2s
# BFGS accepted loss=2.836e-05 elapsed=568.4s
# BFGS accepted loss=2.791e-05 elapsed=569.6s
# BFGS accepted loss=2.759e-05 elapsed=570.8s
# BFGS accepted loss=2.722e-05 elapsed=572.0s
# BFGS accepted loss=2.705e-05 elapsed=573.1s
# BFGS accepted loss=2.679e-05 elapsed=574.3s
# BFGS accepted loss=2.651e-05 elapsed=575.6s
# BFGS accepted loss=2.630e-05 elapsed=576.7s
# BFGS accepted loss=2.619e-05 elapsed=579.1s
# BFGS accepted loss=2.602e-05 elapsed=580.3s
# BFGS accepted loss=2.599e-05 elapsed=581.5s
# BFGS accepted loss=2.593e-05 elapsed=582.7s
# BFGS accepted loss=2.582e-05 elapsed=583.9s
# BFGS accepted loss=2.567e-05 elapsed=585.1s
# BFGS accepted loss=2.559e-05 elapsed=586.3s
# BFGS accepted loss=2.548e-05 elapsed=587.5s
# BFGS accepted loss=2.543e-05 elapsed=588.7s
# BFGS accepted loss=2.537e-05 elapsed=589.9s
# BFGS accepted loss=2.530e-05 elapsed=591.1s
# BFGS accepted loss=2.527e-05 elapsed=592.3s
# BFGS accepted loss=2.522e-05 elapsed=593.5s
# BFGS accepted loss=2.517e-05 elapsed=594.7s
# BFGS accepted loss=2.512e-05 elapsed=595.9s
# BFGS accepted loss=2.505e-05 elapsed=597.0s
# BFGS accepted loss=2.504e-05 elapsed=598.2s
# BFGS accepted loss=2.501e-05 elapsed=599.4s
# BFGS accepted loss=2.495e-05 elapsed=600.6s
# BFGS accepted loss=2.486e-05 elapsed=601.8s
# BFGS accepted loss=2.478e-05 elapsed=603.0s
# BFGS accepted loss=2.477e-05 elapsed=604.2s
# BFGS accepted loss=2.475e-05 elapsed=605.4s
# BFGS accepted loss=2.471e-05 elapsed=606.6s
# BFGS accepted loss=2.464e-05 elapsed=607.8s
# BFGS accepted loss=2.453e-05 elapsed=609.0s
# BFGS accepted loss=2.446e-05 elapsed=610.2s
# BFGS accepted loss=2.437e-05 elapsed=611.4s
# BFGS accepted loss=2.427e-05 elapsed=612.6s
# BFGS accepted loss=2.421e-05 elapsed=615.0s
# BFGS accepted loss=2.414e-05 elapsed=616.2s
# BFGS accepted loss=2.406e-05 elapsed=617.4s
# BFGS accepted loss=2.395e-05 elapsed=618.6s
# BFGS accepted loss=2.385e-05 elapsed=619.8s
# BFGS accepted loss=2.372e-05 elapsed=621.0s
# BFGS accepted loss=2.359e-05 elapsed=622.2s
# BFGS accepted loss=2.347e-05 elapsed=623.4s
# BFGS accepted loss=2.335e-05 elapsed=624.5s
# BFGS accepted loss=2.329e-05 elapsed=625.8s
# BFGS accepted loss=2.320e-05 elapsed=627.0s
# BFGS accepted loss=2.309e-05 elapsed=628.2s
# BFGS accepted loss=2.301e-05 elapsed=630.5s
# BFGS accepted loss=2.297e-05 elapsed=631.7s
# BFGS accepted loss=2.290e-05 elapsed=632.9s
# BFGS accepted loss=2.283e-05 elapsed=634.1s
# BFGS accepted loss=2.272e-05 elapsed=635.3s
# BFGS accepted loss=2.268e-05 elapsed=636.5s
# BFGS accepted loss=2.261e-05 elapsed=637.7s
# BFGS accepted loss=2.250e-05 elapsed=638.9s
# BFGS accepted loss=2.240e-05 elapsed=640.1s
# BFGS accepted loss=2.236e-05 elapsed=642.5s
# BFGS accepted loss=2.231e-05 elapsed=643.7s
# BFGS accepted loss=2.225e-05 elapsed=644.9s
# BFGS accepted loss=2.220e-05 elapsed=646.1s
# BFGS accepted loss=2.218e-05 elapsed=647.3s
# BFGS accepted loss=2.214e-05 elapsed=648.5s
# BFGS accepted loss=2.210e-05 elapsed=649.7s
# BFGS accepted loss=2.209e-05 elapsed=650.8s
# BFGS accepted loss=2.207e-05 elapsed=652.0s
# BFGS accepted loss=2.204e-05 elapsed=653.2s
# BFGS accepted loss=2.200e-05 elapsed=654.4s
# BFGS accepted loss=2.198e-05 elapsed=655.6s
# BFGS accepted loss=2.196e-05 elapsed=656.8s
# BFGS accepted loss=2.193e-05 elapsed=658.0s
# BFGS accepted loss=2.188e-05 elapsed=659.2s
# BFGS accepted loss=2.185e-05 elapsed=660.4s
# BFGS accepted loss=2.181e-05 elapsed=661.6s
# BFGS accepted loss=2.176e-05 elapsed=662.8s
# BFGS accepted loss=2.169e-05 elapsed=664.0s
# BFGS accepted loss=2.162e-05 elapsed=665.2s
# BFGS accepted loss=2.159e-05 elapsed=667.6s
# BFGS accepted loss=2.155e-05 elapsed=668.8s
# BFGS accepted loss=2.151e-05 elapsed=670.0s
# BFGS accepted loss=2.148e-05 elapsed=671.2s
# BFGS accepted loss=2.145e-05 elapsed=672.4s
# BFGS accepted loss=2.142e-05 elapsed=673.6s
# BFGS accepted loss=2.141e-05 elapsed=674.8s
# BFGS accepted loss=2.139e-05 elapsed=676.0s
# BFGS accepted loss=2.137e-05 elapsed=677.2s
# BFGS accepted loss=2.135e-05 elapsed=679.5s
# BFGS accepted loss=2.134e-05 elapsed=680.7s
# BFGS accepted loss=2.133e-05 elapsed=681.9s
# BFGS accepted loss=2.132e-05 elapsed=683.1s
# BFGS accepted loss=2.130e-05 elapsed=684.3s
#          Current function value: 0.000021
#          Iterations: 500
#          Function evaluations: 573
#          Gradient evaluations: 573
# [0:1000] done loss=2.130e-05 iters=500 evals=573 bad=0
# BFGS minutes: 18.27890952825546
# final loss: 2.1297863952821135e-05 success: False Maximum number of iterations has been exceeded.
# /usr/local/lib/python3.12/dist-packages/scipy/optimize/_minimize.py:779: OptimizeWarning: Maximum number of iterations has been exceeded.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)

# %% [markdown]
# ## Final diagnostics and save

# %%
(final_loss, (final_components, final_roots, final_shell, u0_fit)) = loss_only(
    params, t_full, hp_full, hc_full, LOSS_WEIGHTS
)
final_loss.block_until_ready()
print("final loss:", float(final_loss))
print("raw [waveform, Ricci, frequency, boundary]:", np.asarray(final_components))
print("mean horizon proxy:", float(jnp.mean(final_roots)))

errors = np.asarray(metric_errors_jit(params))
labels = ["g_tt", "g_rr", "g_thth", "g_phph", "g_tph"]
radii = [2, 3, 4, 5, 6, 12, 20]
print("\nMetric relative L2 error across theta (%)")
print("component", *[f"r={r}" for r in radii])
for label, row in zip(labels, errors):
    print(label, *[f"{x:.3f}" for x in row])

trajectory = jax.jit(integrate_network)(
    params["metric"], u0_fit, t_full
)
hp_pred, hc_pred = jax.vmap(
    lambda theta: create_gravityWave(t_full, trajectory, a_true, theta_obs=theta)
)(theta_observed.astype(t_full.dtype))

print("Recovered u0:", np.asarray(u0_fit))
print("True u0:", np.asarray(U0))
print("Mass shell:", float(final_shell))

fig, axes = plt.subplots(2, 1, figsize=(11, 6), sharex=True)
axes[0].plot(np.asarray(t_full), np.asarray(hp_full[0]), label="True")
axes[0].plot(np.asarray(t_full), np.asarray(hp_pred[0]), "--", label="JAX Sonar")
axes[0].set_ylabel(r"$h_+$")
axes[0].legend()
axes[1].plot(np.asarray(t_full), np.asarray(hc_full[0]), label="True")
axes[1].plot(np.asarray(t_full), np.asarray(hc_pred[0]), "--", label="JAX Sonar")
axes[1].set_ylabel(r"$h_\times$")
axes[1].set_xlabel("t")
axes[1].legend()
plt.tight_layout()

save_checkpoint(FINAL_PATH, params, len(schedule) - 1, schedule[-1][1] - 1, n, histories)
print("saved:", FINAL_PATH)
# Out:
# final loss: 2.1297863952346695e-05
# raw [waveform, Ricci, frequency, boundary]: [2.31211903e-06 3.54117047e-06 1.16157615e-04 2.85967621e-06]
# mean horizon proxy: 1.5228988938517962
#
# Metric relative L2 error across theta (%)
# component r=2 r=3 r=4 r=5 r=6 r=12 r=20
# g_tt 4.756 0.429 0.154 0.091 0.072 0.035 0.021
# g_rr 7.368 0.716 0.166 0.060 0.028 0.024 0.025
# g_thth 1.641 0.446 0.179 0.117 0.102 0.055 0.026
# g_phph 2.400 0.732 0.305 0.151 0.083 0.006 0.002
# g_tph 2.974 2.070 1.262 0.512 0.222 2.473 3.694
# Recovered u0: [ 0.         10.00004727  0.78616537  0.         -0.96053749  0.
#   0.          2.66104635]
# True u0: [ 0.         10.          0.78539816  0.         -0.96048519  0.
#   0.          2.66185247]
# Mass shell: 1.6748646642099556e-10
# saved: /content/drive/MyDrive/joint_ic_metric_matched_forward_seed0_final.npz

# %%
ic = np.asarray(histories["monitor_ic"])
metric = np.asarray(histories["monitor_metric"])
steps = np.arange(len(ic))

ic_true = np.asarray([
    U0[1],
    U0[2],
    -U0[4],
    U0[7],
], dtype=float)

ic_error = 100 * np.abs((ic - ic_true) / ic_true)
ic_error = np.maximum(ic_error, 1e-12)

metric_labels = [
    r"$g_{tt}$", r"$g_{rr}$", r"$g_{\theta\theta}$",
    r"$g_{\phi\phi}$", r"$g_{t\phi}$",
]

fig, ax = plt.subplots(2, 2, figsize=(12, 9))

# r-theta path
ax[0, 0].plot(ic[:, 0], ic[:, 1], ".-", alpha=0.6)
ax[0, 0].plot(ic[0, 0], ic[0, 1], "ks", label="Start")
ax[0, 0].plot(ic_true[0], ic_true[1], "r*", ms=14, label="Truth")
ax[0, 0].set(xlabel="r", ylabel=r"$\theta$", title="IC path: r, theta")
ax[0, 0].legend()

# E-Lz path
ax[0, 1].plot(ic[:, 2], ic[:, 3], ".-", alpha=0.6)
ax[0, 1].plot(ic[0, 2], ic[0, 3], "ks", label="Start")
ax[0, 1].plot(ic_true[2], ic_true[3], "r*", ms=14, label="Truth")
ax[0, 1].set(xlabel="E", ylabel=r"$L_z$", title="IC path: E, Lz")
ax[0, 1].legend()

# IC errors
for i, label in enumerate(["r", r"$\theta$", "E", r"$L_z$"]):
    ax[1, 0].plot(steps, ic_error[:, i], label=label)

ax[1, 0].set_yscale("log")
ax[1, 0].set(
    xlabel="Recorded optimizer step",
    ylabel="Absolute relative error (%)",
    title="IC errors",
)
ax[1, 0].legend()

# Metric errors
for i, label in enumerate(metric_labels):
    ax[1, 1].plot(steps, metric[:, i], label=label)

ax[1, 1].set_yscale("log")
ax[1, 1].set(
    xlabel="Recorded optimizer step",
    ylabel="Mean relative error (%)",
    title="Metric errors, r ≥ 3",
)
ax[1, 1].legend()

plt.tight_layout()

# %%
def rel_L2(hp, hc):
    true = hp_full[0] + 1j * hc_full[0]
    pred = hp + 1j * hc
    return 100 * jnp.linalg.norm(pred - true) / jnp.linalg.norm(true)

def wave(traj):
    return create_gravityWave(
        t_full, traj, a_true,
        theta_obs=theta_observed[0].astype(t_full.dtype),
    )

u_true = U0.astype(t_full.dtype)
u_fit  = u0_fit.astype(t_full.dtype)

cases = {
    "Kerr metric + true IC":
        wave(jax.jit(integrate_kerr)(u_true, t_full)),

    "Kerr metric + learned IC":
        wave(jax.jit(integrate_kerr)(u_fit, t_full)),

    "Learned metric + true IC":
        wave(jax.jit(integrate_network)(params["metric"], u_true, t_full)),

    "Learned metric + learned IC":
        wave(jax.jit(integrate_network)(params["metric"], u_fit, t_full)),
}

for name, (hp, hc) in cases.items():
    print(f"{name:30s}: {float(rel_L2(hp, hc)):.6f}%")
# Out:
# Kerr metric + true IC         : 0.012373%
# Kerr metric + learned IC      : 71.465797%
# Learned metric + true IC      : 68.482125%
# Learned metric + learned IC   : 0.152057%

# %% [markdown]
# ## Runtime notes
#
# - The first call for each new `(window length, dtype)` includes XLA compilation.
# - Later calls reuse the compiled executable.
# - BFGS retains float64 because the original notebook explicitly required it.
#   On T4-class GPUs float64 may be slower than CPU; benchmark the BFGS phase.
# - Full 96-point Ricci and 320-point boundary grids remain unchanged.
# - No stochastic Ricci subsampling: BFGS sees a deterministic objective.
